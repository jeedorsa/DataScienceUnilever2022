# %%
class LibretaDeNotas:
    
    def __init__(self):
        self.alumnos = dict()
        n_alumnos = int(input())
        for i in range(n_alumnos):
            nombre = input(f"Nombre de alumno {i+1}: ")
            self.alumnos[nombre] = list()
            nota = float(input("Ingrese la siguiente nota: "))
            while nota >= 0:
                self.alumnos[nombre].append(nota)
                nota = float(input("Ingrese la siguiente nota: "))
    
    def mostrar_alumnos(self):
        for nombre, notas in self.alumnos.items():
            print(f"Promedio {nombre}: {sum(notas)/len(notas)}")

# %%
libreta = LibretaDeNotas()
libreta.mostrar_alumnos()
# Out:
# 3
# Nombre de alumno 1: Ana
# Ingrese la siguiente nota: 7
# Ingrese la siguiente nota: 2.5
# Ingrese la siguiente nota: -1
# Nombre de alumno 2: Bárbara
# Ingrese la siguiente nota: 4
# Ingrese la siguiente nota: 4.3
# Ingrese la siguiente nota: 4.6
# Ingrese la siguiente nota: 3.5
# Ingrese la siguiente nota: -100
# Nombre de alumno 3: Camila
# Ingrese la siguiente nota: 3
# Ingrese la siguiente nota: 3.4
# Ingrese la siguiente nota: 7
# Ingrese la siguiente nota: 4
# Ingrese la siguiente nota: 5.2
# Ingrese la siguiente nota: -33
# Promedio Ana: 4.75
# Promedio Bárbara: 4.1
# Promedio Camila: 4.52
