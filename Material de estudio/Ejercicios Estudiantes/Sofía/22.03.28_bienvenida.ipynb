# %%
1+1
# Out:
# 2

# %%
print("Bienvenidas al bootcamp futuras Data Scientist!")
# Out:
# Bienvenidas al bootcamp futuras Data Scientist!

# %%
num = 5
if num % 2 == 0:
    print('par')
else:
    print('impar')
# Out:
# impar
