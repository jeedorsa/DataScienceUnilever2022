# %%
filename = "clase10.csv"
import pandas as pd
df=pd.read_csv(filename)
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDERNUMBER       2823 non-null   int64
#  1   QUANTITYORDERED   2823 non-null   int64
#  2   PRICEEACH         2823 non-null   float64
#  3   ORDERLINENUMBER   2823 non-null   int64
#  4   SALES             2823 non-null   float64
#  5   ORDERDATE         2823 non-null   object
#  6   STATUS            2823 non-null   object
#  7   QTR_ID            2823 non-null   int64
#  8   MONTH_ID          2474 non-null   float64
#  9   YEAR_ID           1478 non-null   float64
#  10  PRODUCTLINE       2823 non-null   object
#  11  MSRP              2823 non-null   int64
#  12  PRODUCTCODE       2823 non-null   object
#  13  CUSTOMERNAME      2823 non-null   object
#  14  PHONE             2823 non-null   object
#  15  ADDRESSLINE1      2823 non-null   object
# ...

# %%
import pandas as pd
import numpy as np

# %%
check_year=df["YEAR_ID"].unique()

# %%
check_year
# Out:
# array([2003.,   nan, 2005.])

# %% [markdown]
# reemplazar nan por 2004

# %%
df["YEAR_ID"]=df["YEAR_ID"].replace(np.nan, 2004)

# %%
check_month=df["MONTH_ID"].unique()

# %%
check_month
# Out:
# array([ 2.,  5.,  7.,  8., 10., 11., 12.,  1., nan,  6.,  3.])

# %%
df["MONTH_ID"].head(13)
# Out:
# 0      2.0
# 1      5.0
# 2      7.0
# 3      8.0
# 4     10.0
# 5     10.0
# 6     11.0
# 7     11.0
# 8     12.0
# 9      1.0
# 10     2.0
# 11     NaN
# 12     5.0
# Name: MONTH_ID, dtype: float64

# %%
df["ORDERDATE"]=pd.to_datetime(df["ORDERDATE"], format="%Y-%m-%d %H:%M", infer_datetime_format=True)
#df["ORDENATE"].dt.strftime( )
df["ORDERDATE2"]=df["ORDERDATE"].apply(lambda x: int(x.strftime("%m")) )
df["ORDERDATE2"]
df["ORDERDATE2"]=df["ORDERDATE2"].apply(lambda x: np.float64(x) )
df[["MONTH_ID","ORDERDATE2"]][df["MONTH_ID"]!=df["ORDERDATE2"]]
# Out:
#       MONTH_ID  ORDERDATE2
# 11         NaN         4.0
# 16         NaN         9.0
# 24         NaN         4.0
# 30         NaN         9.0
# 42         NaN         9.0
# ...        ...         ...
# 2785       NaN         9.0
# 2795       NaN         4.0
# 2798       NaN         4.0
# 2801       NaN         9.0
# 2813       NaN         9.0
#
# [349 rows x 2 columns]

# %%
df["ORDERDATE"]=df["ORDERDATE2"]
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#       ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... ADDRESSLINE2  \
# ...

# %%
min=df[["ORDERDATE2"]][df["MONTH_ID"]!=df["ORDERDATE2"]] #identifico los valores que necesito
Lista=df['MONTH_ID'].index[df['MONTH_ID'].isna()].tolist() #obtengo los indices en donde voy a reemplazar
cont =0 #contador para ingresar en la lista
for j in Lista:

  df["MONTH_ID"][j]=min['ORDERDATE2'].iloc[cont] #recorremos los valores y los ingresamos en los indices del df
  cont=cont+1# debe aumentar el valor para recorrer los valores
print(sum(df['MONTH_ID'].isna()))#revisamos que no tenga NaN

df.head(20) #miramos las posciones 11 y 16 que tenian NaN

# %%
df["MONTH_ID"]=df[["ORDERDATE2"]][df["MONTH_ID"]!=df["ORDERDATE2"]]
df[["ORDERDATE2"]][df["MONTH_ID"]!=df["ORDERDATE2"]]
# Out:
#       ORDERDATE2
# 11           4.0
# 16           9.0
# 24           4.0
# 30           9.0
# 42           9.0
# ...          ...
# 2785         9.0
# 2795         4.0
# 2798         4.0
# 2801         9.0
# 2813         9.0
#
# [349 rows x 1 columns]

# %%
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#       ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... ADDRESSLINE2  \
# ...
