# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df= pd.read_csv("EPL_Set.csv")
df
# Out:
#      Div      Date     HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 0     E0  14/08/93      Arsenal        Coventry     0     3   A   NaN   NaN
# 1     E0  14/08/93  Aston Villa             QPR     4     1   H   NaN   NaN
# 2     E0  14/08/93      Chelsea       Blackburn     1     2   A   NaN   NaN
# 3     E0  14/08/93    Liverpool  Sheffield Weds     2     0   H   NaN   NaN
# 4     E0  14/08/93     Man City           Leeds     1     1   D   NaN   NaN
# ...   ..       ...          ...             ...   ...   ...  ..   ...   ...
# 9659  E0  13/05/18    Newcastle         Chelsea     3     0   H   1.0   0.0
# 9660  E0  13/05/18  Southampton        Man City     0     1   A   0.0   0.0
# 9661  E0  13/05/18      Swansea           Stoke     1     2   A   1.0   2.0
# 9662  E0  13/05/18    Tottenham       Leicester     5     4   H   1.0   2.0
# 9663  E0  13/05/18     West Ham         Everton     3     1   H   1.0   0.0
#
#       HTR   Season
# 0     NaN  1993-94
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9664 entries, 0 to 9663
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Div       9664 non-null   object
#  1   Date      9664 non-null   object
#  2   HomeTeam  9664 non-null   object
#  3   AwayTeam  9664 non-null   object
#  4   FTHG      9664 non-null   int64
#  5   FTAG      9664 non-null   int64
#  6   FTR       9664 non-null   object
#  7   HTHG      8740 non-null   float64
#  8   HTAG      8740 non-null   float64
#  9   HTR       8740 non-null   object
#  10  Season    9664 non-null   object
# dtypes: float64(2), int64(2), object(7)
# memory usage: 830.6+ KB

# %%
df['Date'] = pd.to_datetime(df['Date'])

df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9664 entries, 0 to 9663
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Div       9664 non-null   object
#  1   Date      9664 non-null   datetime64[ns]
#  2   HomeTeam  9664 non-null   object
#  3   AwayTeam  9664 non-null   object
#  4   FTHG      9664 non-null   int64
#  5   FTAG      9664 non-null   int64
#  6   FTR       9664 non-null   object
#  7   HTHG      8740 non-null   float64
#  8   HTAG      8740 non-null   float64
#  9   HTR       8740 non-null   object
#  10  Season    9664 non-null   object
# dtypes: datetime64[ns](1), float64(2), int64(2), object(6)
# memory usage: 830.6+ KB
#               FTHG         FTAG         HTHG         HTAG
# count  9664.000000  9664.000000  8740.000000  8740.000000
# mean      1.523903     1.121482     0.685469     0.488444
# std       1.301671     1.121667     0.833581     0.710524
# ...

# %% [markdown]
# Generar 6 graficos con 6 equipos diferentes, tomando diferentes filtros de tiempo

# %%
df.fillna(0)
# Out:
#      Div       Date     HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 0     E0 1993-08-14      Arsenal        Coventry     0     3   A   0.0   0.0
# 1     E0 1993-08-14  Aston Villa             QPR     4     1   H   0.0   0.0
# 2     E0 1993-08-14      Chelsea       Blackburn     1     2   A   0.0   0.0
# 3     E0 1993-08-14    Liverpool  Sheffield Weds     2     0   H   0.0   0.0
# 4     E0 1993-08-14     Man City           Leeds     1     1   D   0.0   0.0
# ...   ..        ...          ...             ...   ...   ...  ..   ...   ...
# 9659  E0 2018-05-13    Newcastle         Chelsea     3     0   H   1.0   0.0
# 9660  E0 2018-05-13  Southampton        Man City     0     1   A   0.0   0.0
# 9661  E0 2018-05-13      Swansea           Stoke     1     2   A   1.0   2.0
# 9662  E0 2018-05-13    Tottenham       Leicester     5     4   H   1.0   2.0
# 9663  E0 2018-05-13     West Ham         Everton     3     1   H   1.0   0.0
#
#      HTR   Season
# 0      0  1993-94
# ...

# %%
home_team_chelsea = df['HomeTeam']=="Chelsea"
periodo= df["Date"]<"1994-08-10"
df1=df[home_team_chelsea&periodo]
X1=df1.FTHG
home_team_liverpool = df['HomeTeam']=="Liverpool"
periodo= df["Date"]<"1994-08-10"
df2=df[home_team_liverpool&periodo]
x2=df2.FTHG
home_team_arsenal = df['HomeTeam']=="Arsenal"
periodo= df["Date"]<"1994-08-10"
df3=df[home_team_arsenal&periodo]
x3=df3.FTHG
df1
# Out:
#     Div       Date HomeTeam          AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 2    E0 1993-08-14  Chelsea         Blackburn     1     2   A   NaN   NaN
# 38   E0 1993-08-25  Chelsea               QPR     2     0   H   NaN   NaN
# 47   E0 1993-08-28  Chelsea    Sheffield Weds     1     1   D   NaN   NaN
# 68   E0 1993-11-09  Chelsea        Man United     1     0   H   NaN   NaN
# 90   E0 1993-09-25  Chelsea         Liverpool     1     0   H   NaN   NaN
# 111  E0 1993-10-16  Chelsea           Norwich     1     2   A   NaN   NaN
# 134  E0 1993-10-30  Chelsea            Oldham     0     1   A   NaN   NaN
# 156  E0 1993-11-20  Chelsea           Arsenal     0     2   A   NaN   NaN
# 165  E0 1993-11-22  Chelsea          Man City     0     0   D   NaN   NaN
# 206  E0 1993-11-12  Chelsea           Ipswich     1     1   D   NaN   NaN
# 236  E0 1993-12-28  Chelsea         Newcastle     1     0   H   NaN   NaN
# 258  E0 1994-03-01  Chelsea           Everton     4     2   H   NaN   NaN
# ...

# %%
plt.figure(dpi=1000)
plt.ylabel("Victorias en casa")
plt.xlabel("Temporadas")
plt.plot( df1.FTHG, 'r.--',
         df2.FTHG, 'bs-',
         df3.FTHG,  'g^:')

plt.show()

# %%
away_team_chelsea = df['AwayTeam']=="Chelsea"
periodo= df["Date"]<"1994-08-10"
df4=df[away_team_chelsea&periodo]
X4=df4.FTHG
away_team_liverpool = df['AwayTeam']=="Liverpool"
periodo= df["Date"]<"1994-08-10"
df5=df[away_team_liverpool&periodo]
x5=df5.FTHG
away_team_arsenal = df["AwayTeam"]=="Arsenal"
periodo= df["Date"]<"1994-08-10"
df6=df[away_team_arsenal&periodo]
x6=df6.FTHG

plt.figure(dpi=1000)
plt.ylabel("Victorias como visitante")
plt.xlabel("Temporadas")
plt.plot( df4.FTHG, 'r.--',
         df5.FTHG, 'bs-',
         df6.FTHG,  'g^:')
plt.title("Partidos entre desde 1993-08-14 hasta 1994-08-10 como visitantes ")
plt.legend( ['Chelsea', 'Liverpool', 'Arsenal'])

plt.show()

# %%
plt.figure(dpi=1000)
plt.ylabel("Victorias")
plt.xlabel("Temporadas")
plt.plot( df4.FTHG, 'r.--',
         df1.FTHG, 'bs-',)
plt.title("Partidos del Chelsea entre desde 1993-08-14 hasta 1994-08-10 ")
plt.legend( ['Visitante', 'Local'])

plt.show()

# %%
away_team_chelsea = df['AwayTeam']=="Chelsea"
periodo= df["Date"]==(m%)
df4=df[away_team_chelsea&periodo]
X4=df4.FTHG
# Out:
#   File "C:\Users\nicol\AppData\Local\Temp/ipykernel_2476/3393014630.py", line 2
#     periodo= df["Date"]==(m%)
#                             ^
# SyntaxError: invalid syntax

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9664 entries, 0 to 9663
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Div       9664 non-null   object
#  1   Date      9664 non-null   datetime64[ns]
#  2   HomeTeam  9664 non-null   object
#  3   AwayTeam  9664 non-null   object
#  4   FTHG      9664 non-null   int64
#  5   FTAG      9664 non-null   int64
#  6   FTR       9664 non-null   object
#  7   HTHG      8740 non-null   float64
#  8   HTAG      8740 non-null   float64
#  9   HTR       8740 non-null   object
#  10  Season    9664 non-null   object
# dtypes: datetime64[ns](1), float64(2), int64(2), object(6)
# memory usage: 830.6+ KB

# %%
import datetime

# %%
s=df['Date'][0:1].dt.month_name()
s
# Out:
# 0    August
# Name: Date, dtype: object

# %%
df['Mes']=df['Date'].dt.month_name()
df
df['Year'] = pd.DatetimeIndex(df['Date']).year
df
# Out:
#      Div       Date     HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 0     E0 1993-08-14      Arsenal        Coventry     0     3   A   NaN   NaN
# 1     E0 1993-08-14  Aston Villa             QPR     4     1   H   NaN   NaN
# 2     E0 1993-08-14      Chelsea       Blackburn     1     2   A   NaN   NaN
# 3     E0 1993-08-14    Liverpool  Sheffield Weds     2     0   H   NaN   NaN
# 4     E0 1993-08-14     Man City           Leeds     1     1   D   NaN   NaN
# ...   ..        ...          ...             ...   ...   ...  ..   ...   ...
# 9659  E0 2018-05-13    Newcastle         Chelsea     3     0   H   1.0   0.0
# 9660  E0 2018-05-13  Southampton        Man City     0     1   A   0.0   0.0
# 9661  E0 2018-05-13      Swansea           Stoke     1     2   A   1.0   2.0
# 9662  E0 2018-05-13    Tottenham       Leicester     5     4   H   1.0   2.0
# 9663  E0 2018-05-13     West Ham         Everton     3     1   H   1.0   0.0
#
#       HTR   Season     Mes  Year
# ...

# %%
#partidos jugados por John Terry
##John Terry, 717,1998-2017
home_team_chelsea = df['HomeTeam']=="Chelsea"
away_team_chelsea = df['AwayTeam']=="Chelsea"
ingreso_harris= df["Year"]>1996
salida_harris= df["Year"]<2019
fig = plt.figure(dpi=100)
dfp=df[away_team_chelsea | home_team_chelsea]
df4=dfp[ingreso_harris & salida_harris]
# Out:
# C:\Users\nicol\AppData\Local\Temp/ipykernel_2476/385379240.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df4=dfp[ingreso_harris & salida_harris]

# %%
df4
# Out:
#      Div       Date       HomeTeam      AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 1504  E0 1997-01-01        Chelsea     Liverpool     1     0   H   1.0   0.0
# 1515  E0 1997-11-01  Nott'm Forest       Chelsea     2     0   H   1.0   0.0
# 1520  E0 1997-01-18        Chelsea         Derby     3     1   H   2.0   1.0
# 1545  E0 1997-01-02      Tottenham       Chelsea     1     2   A   0.0   1.0
# 1554  E0 1997-02-22        Chelsea    Man United     1     1   D   1.0   0.0
# ...   ..        ...            ...           ...   ...   ...  ..   ...   ...
# 9620  E0 2018-04-19        Burnley       Chelsea     1     2   A   0.0   1.0
# 9634  E0 2018-04-28        Swansea       Chelsea     0     1   A   0.0   1.0
# 9646  E0 2018-06-05        Chelsea     Liverpool     1     0   H   1.0   0.0
# 9649  E0 2018-09-05        Chelsea  Huddersfield     1     1   D   0.0   0.0
# 9659  E0 2018-05-13      Newcastle       Chelsea     3     0   H   1.0   0.0
#
#      HTR   Season        Mes  Year
# ...

# %%
fig=plt.figure(dpi=500)
fig.suptitle("Estudio del efecto de la llegada y la ida de John Terry", fontsize=14, fontweight="bold")
ax1=fig.add_subplot(1,3,1)
ax1.set_title("John Terry")
ax1.set_xlabel("Partidos de John Terry")
ax1.set_ylabel("Temporadas")
ax1.annotate('Aquí llega John Terry', xy=(1997,6), xytext=(2000,7), arrowprops=dict(facecolor='black', shrink=0.02))
ax1.annotate('Aquí se va John Terry', xy=(2018,4), xytext=(2010,7), arrowprops=dict(facecolor='black', shrink=0.02))
ax1.plot( df4.Year,df4.FTHG,'r.--')
ax1.legend( ['Chelsea'])
ax2=fig.add_subplot(1,3,2)
ax2.set_title(" John Terry")
ax2.set_xlabel("Partidos de John Terry")
ax2.set_ylabel("Temporadas")
ax2.annotate('Aquí llega John Terry', xy=(1997,6), xytext=(2000,7), arrowprops=dict(facecolor='black', shrink=0.02))
ax2.annotate('Aquí se va John Terry', xy=(2018,4), xytext=(2010,7), arrowprops=dict(facecolor='black', shrink=0.02))
ax2.plot( df4.Year,df4.FTHG,'r.--')
ax2.legend( ['Chelsea'])
ax3=fig.add_subplot(1,3,3)
ax3.set_title("John Terry")
ax3.set_xlabel("Partidos de John Terry")
ax3.set_ylabel("Temporadas")
ax3.annotate('Aquí llega John Terry', xy=(1997,6), xytext=(2000,7), arrowprops=dict(facecolor='black', shrink=0.02))
ax3.annotate('Aquí se va John Terry', xy=(2018,4), xytext=(2010,7), arrowprops=dict(facecolor='black', shrink=0.02))
ax3.plot( df4.Year,df4.FTHG,'r.--')
ax3.legend( ['Chelsea'])
plt.show()

# %%
df4.FTHG,
# Out:
# (1504    1
#  1515    2
#  1520    3
#  1545    1
#  1554    1
#         ..
#  9620    1
#  9634    0
#  9646    1
#  9649    1
#  9659    3
#  Name: FTHG, Length: 816, dtype: int64,)

# %%
df4.Year
# Out:
# 1504    1997
# 1515    1997
# 1520    1997
# 1545    1997
# 1554    1997
#         ...
# 9620    2018
# 9634    2018
# 9646    2018
# 9649    2018
# 9659    2018
# Name: Year, Length: 816, dtype: int64
