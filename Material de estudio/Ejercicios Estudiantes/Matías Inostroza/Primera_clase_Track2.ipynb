# %% [markdown]
# # Introducción al aprendizaje automatico

# %% [markdown]
# El machine learning es genial para:
# - Buenos data sets
# - Progreso para algoritmos, siempre hay cosas nuevas q se pueden implementar
# Estamos en la epoca perfecta para poder generar el aprendizaje automatico, además tenemos el oro del siglo xxi (datos). Por esto es que tiene
# aplicaciones tanto Cientificas como Comerciales.
# Pero ojo machine learning NO es inteligencia artificial
#
# ---
# Algunas de las tareas son
# Aprendizaje supervisado:
# - regresion  (hasta de imagenes)
# - clasificación (reconocimiento de imagenes) (red yolo para clasificación)
# se llama supervisado porque tenemos ground truth o valor con el cual comparar
# dentro de mi data, tengo una parte que es para entrenar y otra para testear.
#
# Aprendizaje no supervisado:
# - Clustering (agrupar)
# - Asociacion
# - link prediction (relaciones entre la data)
# - Data reduction (para dataset muy grandes)
#
# Reinforcement learning:
# neurips conferencia
# redes generativas GAN
# Que el sistema vaya aprendiendo y así se REFUERZA el conocimiento

# %% [markdown]
# Algunos algoritmos:
# Regresión:
# - lineal
# - SVM
# - Random forest
# - MNN
# - Deep neural networks
#
# Clasificación:
# - SVM
# - Random fores
# - MNN

# %% [markdown]
# Problemas tipicos en ML
# - la mayoria de los proyectos fallan, casi un 85%!!!! debido a que no todos son honestos con los datos
# - Etica
#
# Razones para fallar:
# - Hacer la pregunta equivocada o no comprender el problema.
# - Tratar de solucionar un problema erroneo
#     - no tener suficiente data
#     - no tener la data correcta
#     - tener mucha data
# - Contratar personas incorrectas para los cargos
# - USando las herramientas erroneas
# - No tener el modelo correcto
#
#
# Toolbox
# - scikit learn (la clasica)
# - pytorch
# - Tensorflow
# - keras

# %% [markdown]
# SCIKIT-Learn
#
# funciona bien con data exploring (pandas -holoviews)
# Data preprocessing
# Training
# testing
# application
#
# scikit-learn.org

# %% [markdown]
# KERAS
# PAra deep learning

# %% [markdown]
# Data pipelines
# Carga de datos
# limpieza y filtrado
# normalizacion de la data

# %% [markdown]
# como hacemos aprendizaje supervisado?
# 1. seleccionar el modelo haciendonos una pregunta de que quiero hacer
# 2. determinar parametros:
#     - Cuanta data dejo de entrenamiento
#     - cuanto para prueba (test) (el modelo no debe haber visto estos datos cuando lo entrenamos)
#     - validacion
# 3. test model Siempre mostrar metricas de la test no del training
# 4. production
#
# overfitting-> reajustar el modelo (sobreajustarse) nunca sera capaz de generalizar, se genera con entrenando y validando con la misma data, deberia ser 70-30
# underfitting -> el modelo no hace nada y es muy aleatorio

# %%
KE
