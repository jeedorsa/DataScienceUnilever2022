# %%
# Importar files de google colab 
from google.colab import files
# files.upload() despliega una ventana que permite cargar un archivo desde nuestro pc
files.upload()
# Out:
#      <input type="file" id="files-9f85671d-c244-4f9a-bfeb-36afbf9df415" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9f85671d-c244-4f9a-bfeb-36afbf9df415">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving bostonHousing1978.xlsx to bostonHousing1978.xlsx
# ...

# %%
import pandas as pd
# Podemos crear un df con 'read_excel' de pandas mencionando directamente el archivo recientemente subido
df = pd.read_excel('bostonHousing1978.xlsx')
print(df)
# Out:
#         RM  LSTAT  PTRATIO  target
# 0    6.575   4.98     15.3    24.0
# 1    6.421   9.14     17.8    21.6
# 2    7.185   4.03     17.8    34.7
# 3    6.998   2.94     18.7    33.4
# 4    7.147   5.33     18.7    36.2
# ..     ...    ...      ...     ...
# 501  6.593   9.67     21.0    22.4
# 502  6.120   9.08     21.0    20.6
# 503  6.976   5.64     21.0    23.9
# 504  6.794   6.48     21.0    22.0
# 505  6.030   7.88     21.0    11.9
#
# [506 rows x 4 columns]
